# %%
import numpy as np
import pandas as pd

# %%
df_org = pd.read_csv('telecom_customer_churn.csv')

# %%
df_org
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# 0        93225  34.827662 -118.999073                    2  ...
# 1        91206  34.162515 -118.203869                    0  ...
# 2        92627  33.645672 -117.922613                    0  ...
# 3        94553  38.014457 -122.115432                    1  ...
# 4        93010  34.227846 -119.079903                    3  ...
# ...        ...        ...         ...                  ...  ...
# 7038     91941  32.759327 -116.997260                    0  ...
# 7039     95367  37.734971 -120.954271                    1  ...
# 7040     95432  39.108252 -123.645121                    0  ...
# 7041     92075  33.001813 -117.263628                    5  ...
# 7042     96125  39.600599 -120.636358                    1  ...
#
#        Payment Method Monthly Charge Total Charges  Total Refunds  \
# 0         Credit Card          65.60        593.30           0.00
# 1         Credit Card          -4.00        542.40          38.33
# 2     Bank Withdrawal          73.90        280.85           0.00
# 3     Bank Withdrawal          98.00       1237.85           0.00
# 4         Credit Card          83.90        267.40           0.00
# ...               ...            ...           ...            ...
# 7038      Credit Card          55.15        742.90           0.00
# 7039  Bank Withdrawal          85.10       1873.70           0.00
# 7040      Credit Card          50.30         92.75           0.00
# 7041      Credit Card          67.85       4627.65           0.00
# 7042  Bank Withdrawal          59.00       3707.60           0.00
#
#      Total Extra Data Charges Total Long Distance Charges Total Revenue  \
# 0                           0                      381.51        974.81
# 1                          10                       96.21        610.28
# 2                           0                      134.60        415.45
# 3                           0                      361.66       1599.51
# 4                           0                       22.14        289.54
# ...                       ...                         ...           ...
# 7038                        0                      606.84       1349.74
# 7039                        0                      356.40       2230.10
# 7040                        0                       37.24        129.99
# 7041                        0                      142.04       4769.69
# 7042                        0                        0.00       3707.60
#
#       Customer Status   Churn Category                   Churn Reason
# 0              Stayed              NaN                            NaN
# 1              Stayed              NaN                            NaN
# 2             Churned       Competitor  Competitor had better devices
# 3             Churned  Dissatisfaction        Product dissatisfaction
# 4             Churned  Dissatisfaction            Network reliability
# ...               ...              ...                            ...
# 7038           Stayed              NaN                            NaN
# 7039          Churned  Dissatisfaction        Product dissatisfaction
# 7040           Joined              NaN                            NaN
# 7041           Stayed              NaN                            NaN
# 7042           Stayed              NaN                            NaN
#
# [7043 rows x 38 columns]

# %%
df = df_org.copy()
df['client_churned'] = df['Customer Status'] == 'Churned'
df = df[df['Customer Status'] != 'Joined']
columns_to_drop = ['City', 'Latitude', 'Longitude', 'Churn Category', 'Churn Reason', 'Customer Status', 'Customer ID']
df = df.drop(columns_to_drop, axis=1) #Drop All columns with nans
df.dropna(axis=1, how='any', inplace=True)

# %%
df
# Out:
#       Gender  Age Married  Number of Dependents  Zip Code  \
# 0     Female   37     Yes                     0     93225
# 1       Male   46      No                     0     91206
# 2       Male   50      No                     0     92627
# 3       Male   78     Yes                     0     94553
# 4     Female   75     Yes                     0     93010
# ...      ...  ...     ...                   ...       ...
# 7037  Female   36      No                     0     92028
# 7038  Female   20      No                     0     91941
# 7039    Male   40     Yes                     0     95367
# 7041    Male   21     Yes                     0     92075
# 7042    Male   36     Yes                     0     96125
#
#       Number of Referrals  Tenure in Months    Offer Phone Service  \
# 0                       2                 9     None           Yes
# 1                       0                 9     None           Yes
# 2                       0                 4  Offer E           Yes
# 3                       1                13  Offer D           Yes
# 4                       3                 3     None           Yes
# ...                   ...               ...      ...           ...
# 7037                    0                 4     None           Yes
# 7038                    0                13  Offer D           Yes
# 7039                    1                22  Offer D           Yes
# 7041                    5                67  Offer A           Yes
# 7042                    1                63     None            No
#
#      Internet Service        Contract Paperless Billing   Payment Method  \
# 0                 Yes        One Year               Yes      Credit Card
# 1                 Yes  Month-to-Month                No      Credit Card
# 2                 Yes  Month-to-Month               Yes  Bank Withdrawal
# 3                 Yes  Month-to-Month               Yes  Bank Withdrawal
# 4                 Yes  Month-to-Month               Yes      Credit Card
# ...               ...             ...               ...              ...
# 7037               No  Month-to-Month                No  Bank Withdrawal
# 7038              Yes        One Year                No      Credit Card
# 7039              Yes  Month-to-Month               Yes  Bank Withdrawal
# 7041              Yes        Two Year                No      Credit Card
# 7042              Yes        Two Year                No  Bank Withdrawal
#
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 0              65.60         593.30           0.00                         0
# 1              -4.00         542.40          38.33                        10
# 2              73.90         280.85           0.00                         0
# 3              98.00        1237.85           0.00                         0
# 4              83.90         267.40           0.00                         0
# ...              ...            ...            ...                       ...
# 7037           20.95          85.50           0.00                         0
# 7038           55.15         742.90           0.00                         0
# 7039           85.10        1873.70           0.00                         0
# 7041           67.85        4627.65           0.00                         0
# 7042           59.00        3707.60           0.00                         0
#
#       Total Long Distance Charges  Total Revenue  client_churned
# 0                          381.51         974.81           False
# 1                           96.21         610.28           False
# 2                          134.60         415.45            True
# 3                          361.66        1599.51            True
# 4                           22.14         289.54            True
# ...                           ...            ...             ...
# 7037                         8.04          93.54            True
# 7038                       606.84        1349.74           False
# 7039                       356.40        2230.10            True
# 7041                       142.04        4769.69           False
# 7042                         0.00        3707.60           False
#
# [6589 rows x 20 columns]

# %% [markdown]
# ## Leaving some data for Batch Mode

# %%
from sklearn.model_selection import train_test_split

df_curr, df_future = train_test_split(df, test_size=0.2)

# %%
df_future.to_csv('future.csv')

# %% [markdown]
# ## Train, val, test split

# %%
df_train, df_test = train_test_split(df, test_size=0.4, stratify=df['client_churned'])
df_test, df_val = train_test_split(df_test, test_size=0.5, stratify=df_test['client_churned'])

# %%
df_val.to_csv('val.csv')
df_train.to_csv('train.csv')
df_test.to_csv('test.csv')

# %% [markdown]
# # Training

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction import DictVectorizer

# %%
categorical = ['Gender', 'Zip Code', 'Offer', 'Contract', 'Phone Service', 'Internet Service', 'Paperless Billing',
              'Payment Method']
numerical = ['Age', 'Number of Dependents', 'Number of Referrals', 'Tenure in Months', 'Monthly Charge',
            'Total Charges', 'Total Refunds', 'Total Extra Data Charges', 'Total Revenue']
target = 'client_churned'

def preprocess_data(df, dv=None, scaler=None, train=True):
    
    df = df.copy()
    target_vec = df[target]
    df.drop(target, axis=1, inplace=True)
    df[categorical] = df[categorical].astype('str')
    if train:
        scaler = StandardScaler()
        df[numerical] = scaler.fit_transform(df[numerical])
        
        df_dict = df.to_dict(orient='records')
        dv = DictVectorizer()
        X = dv.fit_transform(df_dict)
        return scaler, dv, X, target_vec
    else:
        df[numerical] = scaler.transform(df[numerical])
        df_dict = df.to_dict(orient='records')
        X = dv.transform(df_dict)
        return X, target_vec

# %% [markdown]
# ## Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
scaler, dv, X_train, y_train = preprocess_data(df_train)

# %%
def train(X_train, y_train):

    lr = LogisticRegression(solver='liblinear')
    lr.fit(X_train, y_train)
    
    return lr

# %%
lr = train(X_train, y_train)

# %% [markdown]
# ## Inference

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import fbeta_score

# %%
def predict(X, lr):
    return lr.predict(X)

# %%
balanced_accuracy_score(y_train, predict(X_train, lr))
# Out:
# 0.8677798840321143

# %%
fbeta_score(y_train, predict(X_train, lr), beta=0)
# Out:
# 0.8305555555555556

# %%
X_val, y_val = preprocess_data(df_val, dv, scaler, train=False)

# %%
balanced_accuracy_score(y_val, predict(X_val, lr))
# Out:
# 0.8192213133327291

# %%
fbeta_score(y_val, predict(X_val, lr), beta=0)
# Out:
# 0.7374005305039788

# %%
import xgboost as xgb

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
params = {
    'max_depth': 3,
    'objective': 'binary:logistic', 
}

# %%
booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
# Out:
# [11:26:38] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation-logloss:0.54952
# [1]	validation-logloss:0.46856
# [2]	validation-logloss:0.41636
# [3]	validation-logloss:0.38347
# [4]	validation-logloss:0.35878
# [5]	validation-logloss:0.34137
# [6]	validation-logloss:0.32549
# [7]	validation-logloss:0.31677
# [8]	validation-logloss:0.30179
# [9]	validation-logloss:0.29589
# [10]	validation-logloss:0.29051
# [11]	validation-logloss:0.28730
# [12]	validation-logloss:0.28405
# [13]	validation-logloss:0.28167
# [14]	validation-logloss:0.27962
# [15]	validation-logloss:0.27695
# [16]	validation-logloss:0.27520
# [17]	validation-logloss:0.27335
# [18]	validation-logloss:0.27252
# [19]	validation-logloss:0.26885
# [20]	validation-logloss:0.26673
# [21]	validation-logloss:0.26587
# [22]	validation-logloss:0.26538
# [23]	validation-logloss:0.26406
# [24]	validation-logloss:0.26255
# [25]	validation-logloss:0.26164
# [26]	validation-logloss:0.26067
# [27]	validation-logloss:0.26054
# [28]	validation-logloss:0.26067
# [29]	validation-logloss:0.25962
# [30]	validation-logloss:0.25903
# [31]	validation-logloss:0.25754
# [32]	validation-logloss:0.25803
# [33]	validation-logloss:0.25810
# [34]	validation-logloss:0.25743
# [35]	validation-logloss:0.25789
# [36]	validation-logloss:0.25704
# [37]	validation-logloss:0.25764
# [38]	validation-logloss:0.25750
# [39]	validation-logloss:0.25650
# [40]	validation-logloss:0.25670
# [41]	validation-logloss:0.25673
# [42]	validation-logloss:0.25666
# [43]	validation-logloss:0.25627
# [44]	validation-logloss:0.25587
# [45]	validation-logloss:0.25563
# [46]	validation-logloss:0.25537
# [47]	validation-logloss:0.25511
# [48]	validation-logloss:0.25575
# [49]	validation-logloss:0.25477
# [50]	validation-logloss:0.25483
# [51]	validation-logloss:0.25470
# [52]	validation-logloss:0.25492
# [53]	validation-logloss:0.25507
# [54]	validation-logloss:0.25511
# [55]	validation-logloss:0.25471
# [56]	validation-logloss:0.25437
# [57]	validation-logloss:0.25388
# [58]	validation-logloss:0.25380
# [59]	validation-logloss:0.25400
# [60]	validation-logloss:0.25424
# [61]	validation-logloss:0.25417
# [62]	validation-logloss:0.25431
# [63]	validation-logloss:0.25425
# [64]	validation-logloss:0.25442
# [65]	validation-logloss:0.25428
# [66]	validation-logloss:0.25450
# [67]	validation-logloss:0.25452
# [68]	validation-logloss:0.25442
# [69]	validation-logloss:0.25438
# [70]	validation-logloss:0.25446
# [71]	validation-logloss:0.25468
# [72]	validation-logloss:0.25463
# [73]	validation-logloss:0.25501
# [74]	validation-logloss:0.25533
# [75]	validation-logloss:0.25441
# [76]	validation-logloss:0.25437
# [77]	validation-logloss:0.25404
# [78]	validation-logloss:0.25435
# [79]	validation-logloss:0.25485
# [80]	validation-logloss:0.25502
# [81]	validation-logloss:0.25527
# [82]	validation-logloss:0.25542
# [83]	validation-logloss:0.25526
# [84]	validation-logloss:0.25586
# [85]	validation-logloss:0.25598
# [86]	validation-logloss:0.25630
# [87]	validation-logloss:0.25666
# [88]	validation-logloss:0.25660
# [89]	validation-logloss:0.25659
# [90]	validation-logloss:0.25679
# [91]	validation-logloss:0.25736
# [92]	validation-logloss:0.25660
# [93]	validation-logloss:0.25719
# [94]	validation-logloss:0.25750
# [95]	validation-logloss:0.25733
# [96]	validation-logloss:0.25756
# [97]	validation-logloss:0.25729
# [98]	validation-logloss:0.25721
# [99]	validation-logloss:0.25750
# [100]	validation-logloss:0.25647
# [101]	validation-logloss:0.25641
# [102]	validation-logloss:0.25678
# [103]	validation-logloss:0.25702
# [104]	validation-logloss:0.25698
# [105]	validation-logloss:0.25730
# [106]	validation-logloss:0.25723
# [107]	validation-logloss:0.25829
# [108]	validation-logloss:0.25835

# %%
def predict_binary(probs):
    return (probs >= 0.5).astype('int')

# %%
probs = booster.predict(valid)

# %%
predict_binary(probs)
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
fbeta_score(y_val, predict_binary(probs), beta=0.2)
# Out:
# 0.8202080237741455
